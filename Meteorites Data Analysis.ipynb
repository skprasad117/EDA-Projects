# %% [markdown]
# ## Question 7 -
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
# - Get all the Earth meteorites that fell before the year 2000
# - Get all the earth meteorites co-ordinates who fell before the year 1970
# - Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset/nasa_meteroite_converted_json_csv.csv")
df.head()
# Out:
#     id  :@computed_region_cbhk_fwbd      name  :@computed_region_nnqa_25f4  \
# 0    1                          NaN    Aachen                          NaN
# 1    2                          NaN    Aarhus                          NaN
# 2    6                          NaN      Abee                          NaN
# 3   10                          NaN  Acapulco                          NaN
# 4  370                          NaN   Achiras                          NaN
#
#    fall  geolocation_coordinates_1  geolocation_coordinates_2  \
# 0  Fell                    6.08333                   50.77500
# 1  Fell                   10.23333                   56.18333
# 2  Fell                 -113.00000                   54.21667
# 3  Fell                  -99.90000                   16.88333
# 4  Fell                  -64.95000                  -33.16667
#
#   geolocation_type      mass nametype     recclass    reclat    reclong  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1000 non-null   int64
#  1   :@computed_region_cbhk_fwbd  133 non-null    float64
#  2   name                         1000 non-null   object
#  3   :@computed_region_nnqa_25f4  134 non-null    float64
#  4   fall                         1000 non-null   object
#  5   geolocation_coordinates_1    988 non-null    float64
#  6   geolocation_coordinates_2    988 non-null    float64
#  7   geolocation_type             988 non-null    object
#  8   mass                         972 non-null    float64
#  9   nametype                     1000 non-null   object
#  10  recclass                     1000 non-null   object
#  11  reclat                       988 non-null    float64
# ...

# %%
df['year']=df['year'].str.split('-').str[0]
df['year'] = df['year'].fillna("0")
df['year'] = df['year'].astype('int64')

# %% [markdown]
# ## 1, Get all the Earth meteorites that fell before the year 2000

# %%
df[df['year']<2000]
# Out:
#         id  :@computed_region_cbhk_fwbd       name  \
# 0        1                          NaN     Aachen
# 1        2                          NaN     Aarhus
# 2        6                          NaN       Abee
# 3       10                          NaN   Acapulco
# 4      370                          NaN    Achiras
# ..     ...                          ...        ...
# 994  24004                          NaN   Timochin
# 995  24009                          NaN   Tirupati
# 997  24011                          NaN      Tjabe
# 998  24012                          NaN   Tjerebon
# 999  24019                          NaN  Tomakovka
#
#      :@computed_region_nnqa_25f4  fall  geolocation_coordinates_1  \
# 0                            NaN  Fell                    6.08333
# 1                            NaN  Fell                   10.23333
# 2                            NaN  Fell                 -113.00000
# 3                            NaN  Fell                  -99.90000
# ...

# %%
len(df[df['year']<2000])
# Out:
# 930

# %% [markdown]
# ### Total 930 meteorit fall before year 2000

# %% [markdown]
# ## 2. Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
# location of all the meterotes co-oridinates fall before year 1970
df[df['year']<1970][['geolocation_coordinates_1','geolocation_coordinates_2']]
# Out:
#      geolocation_coordinates_1  geolocation_coordinates_2
# 0                      6.08333                   50.77500
# 1                     10.23333                   56.18333
# 2                   -113.00000                   54.21667
# 4                    -64.95000                  -33.16667
# 5                     71.80000                   32.10000
# ..                         ...                        ...
# 994                   35.20000                   54.50000
# 995                   79.41667                   13.63333
# 997                  111.53333                   -7.08333
# 998                  106.58333                   -6.66667
# 999                   34.76667                   47.85000
#
# [781 rows x 2 columns]

# %% [markdown]
# ## 3. Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
df[df['mass']>10000]
# Out:
#         id  :@computed_region_cbhk_fwbd        name  \
# 2        6                          NaN        Abee
# 7      392                          NaN        Agen
# 11     424                          NaN         Aïr
# 16     433                          NaN     Akyumak
# 27     466                          NaN  Alfianello
# ..     ...                          ...         ...
# 991  23989                          NaN   Tieschitz
# 992  23998                         34.0      Tilden
# 994  24004                          NaN    Timochin
# 997  24011                          NaN       Tjabe
# 998  24012                          NaN    Tjerebon
#
#      :@computed_region_nnqa_25f4  fall  geolocation_coordinates_1  \
# 2                            NaN  Fell                 -113.00000
# 7                            NaN  Fell                    0.61667
# 11                           NaN  Fell                    8.38333
# 16                           NaN  Fell                   42.81667
# ...

# %%
len(df[df['mass']>10000])
# Out:
# 243

# %% [markdown]
# #### Total 243 meteorites fall having mass more than 10000 Kg
